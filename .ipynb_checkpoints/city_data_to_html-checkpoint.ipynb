# %%
import pandas as pd

# %%
# File to Load (Remember to Change These)
city_date_to_load = "Resources/citydata.csv"

# Read School and Student Data File and store into Pandas DataFrames
city_data = pd.read_csv(city_date_to_load)

# %%
city_data
# Out:
#          City Name  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0         la ronge     55.10    -105.28        24.80      53.0        90.0
# 1            synya     65.37      58.04        22.75      94.0       100.0
# 2          ust-kut     56.79     105.77        35.06      91.0       100.0
# 3         yongzhou     26.46     111.60        59.47      68.0        91.0
# 4          camapua    -19.53     -54.04        85.60      57.0        73.0
# ..             ...       ...        ...          ...       ...         ...
# 679       hamilton     39.18     -84.53        53.60      54.0        40.0
# 680           basi     26.83      76.03        75.20      27.0         0.0
# 681        chapais     49.78     -74.85        30.20      74.0        90.0
# 682       la palma     33.85    -118.05        73.40      53.0        90.0
# 683  pacific grove     36.62    -121.92        68.00      63.0        75.0
#
#      Wind Speed Country          Date
# ...

# %%
city_data = city_data.rename(columns = {'index':'cityID'})

# %%
city_data
# Out:
#          City Name  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0         la ronge     55.10    -105.28        24.80      53.0        90.0
# 1            synya     65.37      58.04        22.75      94.0       100.0
# 2          ust-kut     56.79     105.77        35.06      91.0       100.0
# 3         yongzhou     26.46     111.60        59.47      68.0        91.0
# 4          camapua    -19.53     -54.04        85.60      57.0        73.0
# ..             ...       ...        ...          ...       ...         ...
# 679       hamilton     39.18     -84.53        53.60      54.0        40.0
# 680           basi     26.83      76.03        75.20      27.0         0.0
# 681        chapais     49.78     -74.85        30.20      74.0        90.0
# 682       la palma     33.85    -118.05        73.40      53.0        90.0
# 683  pacific grove     36.62    -121.92        68.00      63.0        75.0
#
#      Wind Speed Country          Date
# ...

# %%
result=city_data.to_html()

# %%
print(result)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City Name</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>la ronge</td>
#       <td>55.10</td>
#       <td>-105.28</td>
#       <td>24.80</td>
#       <td>53.0</td>
#       <td>90.0</td>
#       <td>10.29</td>
#       <td>CA</td>
#       <td>1.603571e+09</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>synya</td>
#       <td>65.37</td>
#       <td>58.04</td>
#       <td>22.75</td>
#       <td>94.0</td>
#       <td>100.0</td>
#       <td>1.32</td>
#       <td>RU</td>
#       <td>1.603571e+09</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ust-kut</td>
#       <td>56.79</td>
#       <td>105.77</td>
# ...
